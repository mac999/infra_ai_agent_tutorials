# %% [markdown]
# ## Install library package

# %%
import sys
sys.version_info

# !pip install tensorflow keras torch transformers datasets accelerate langchain gradio openai ultralytics wandb pandas matplotlib seaborn jupyterlab

# %%
# !pip list

# %% [markdown]
# ## Check PyTorch version

# %%
import torch
torch.cuda.is_available()
torch.__version__
# Out:
# '2.7.1+cu118'

# %%
import transformers, torch
from transformers import pipeline

print(transformers.__version__)
print(torch.cuda.is_available())
# Out:
# 4.54.0
# True

# %% [markdown]
# ## Test library

# %%
from mpl_toolkits import mplot3d

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
import pandas as pd

data = {'Unemployment_Rate': [6.1,5.8,5.7,5.7,5.8,5.6,5.5,5.3,5.2,5.2],
        'Stock_Index_Price': [1500,1520,1525,1523,1515,1540,1545,1560,1555,1565]
       }

df = pd.DataFrame(data,columns=['Unemployment_Rate','Stock_Index_Price'])
df.to_csv("dataset.csv")

df = pd.read_csv("dataset.csv")
display(df)
# Out:
#    Unnamed: 0  Unemployment_Rate  Stock_Index_Price
# 0           0                6.1               1500
# 1           1                5.8               1520
# 2           2                5.7               1525
# 3           3                5.7               1523
# 4           4                5.8               1515
# 5           5                5.6               1540
# 6           6                5.5               1545
# 7           7                5.3               1560
# 8           8                5.2               1555
# 9           9                5.2               1565

# %% [markdown]
# ## Upload and download files in Colab

# %% [markdown]
# #### Upload files to Colab

# %%
from google.colab import files
data_to_load = files.upload()

# %% [markdown]
# Download files from Colab

# %%
from google.colab import files
import shutil

# Replace 'your_file.txt' with the filename you want to download
files.download('your_file.txt')

# Replace 'your_folder' with the folder you want to download as a zip
shutil.make_archive('your_folder', 'zip', 'your_folder')
files.download('your_folder.zip')

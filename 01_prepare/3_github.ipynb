# %% [markdown]
# ## Basic commands in Colab

# %% [markdown]
# #### git command for online development collaboration

# %%
# !git

# %% [markdown]
# #### list files and folders

# %%
# %ls

# %% [markdown]
# #### Current project working directory

# %%
# %pwd
# Out:
# 'f:\\projects\\Book_AI_foundation\\1_3_setup'

# %% [markdown]
# ## Debuing code in Colab
# refer to https://www.geeksforgeeks.org/debugging-in-google-colab/

# %%
# !pip install ipdb
# %pdb on
import ipdb
ipdb.set_trace()
